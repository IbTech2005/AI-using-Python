# %% [markdown]
# <a href="https://colab.research.google.com/github/IbTech2005/AI-using-Python/blob/main/Lab_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Given a list of numbers, separate even and odd numbers into two different lists.
# ate even and odd numbers into two different lists.
# Example
# Input: [10, 21, 34, 41, 56]
# Output:
# Even = [10, 34, 56]
# Odd = [21, 41]

# %%
#1
list = [10,21,34,41,56]
even = []
odd = []
print(f"The give list is {list}")
for num in list:
  if num % 2 == 0:
    even.append(num)
  else:
    odd.append(num)

print(f"The even numbers are {even}")
print(f"The odd numbers are {odd}")
# Out:
# The give list is [10, 21, 34, 41, 56]
# The even numbers are [10, 34, 56]
# The odd numbers are [21, 41]

# %% [markdown]
# 2.Write a program to remove duplicate elements from a list while maintaining the original order.
# Example
# Input: [1,2,2,3,4,4,5]
# Output: [1,2,3,4,5]

# %%
#2
list = [1,2,2,3,4,4,5]
print(f"original list {list}")
result = []

for num in list:
  if num not in result:
   result.append(num)

print(f"The final result is {result}")
# Out:
# original list [1, 2, 2, 3, 4, 4, 5]
# The final result is [1, 2, 3, 4, 5]

# %% [markdown]
# 3.Write a Python program to find the frequency of each element in a list without using dictionary built-in counting functions.

# %%
#3
arr = [1,2,2,3,1,2]
vist = []

for i in range(len(arr)):
  if arr[i] not in vist:
    count = 0
    for j in range(len(arr)):
      if arr[i] == arr[j]:
        count += 1

    print(f"{arr[i]} is {count} times")
    vist.append(arr[i])
# Out:
# 1 is 2 times
# 2 is 3 times
# 3 is 1 times

# %% [markdown]
# 4.Write a Python program to swap two tuples without using a temporary variable.

# %%
#4
a = (1,2)
b = (3,4)

a,b = b,a
print(f"a = {a}")
print(f"b = {b}")
# Out:
# a = (3, 4)
# b = (1, 2)

# %% [markdown]
# 5.Given a tuple of integers, find the maximum and minimum values.

# %%
#5
t = (10,3,22,16,9)
max_num = t[0]
min_num = t[0]
print(f"The original tuple is {t}")
for i in t:
  if num > max_num:
    max_value = num
  elif num < min_num:
    min_num = num

print(f"Maximum number is {max_num}")
print(f"Minimum number is {min_num}")
# Out:
# The original tuple is (10, 3, 22, 16, 9)
# Maximum number is 10
# Minimum number is 5

# %% [markdown]
# 6.Write a program to convert a list of tuples into a dictionary.
# Example
# Input: [("A",10), ("B",20), ("C",30)]
# Output: {'A':10, 'B':20, 'C':30}

# %%
#6
lst = [('A' , 10), ('B' , 20), ('C' , 30)]
print(f"The original list is {lst}")

d = dict(lst)

print(f"Dictionary : {d}")
# Out:
# The original list is [('A', 10), ('B', 20), ('C', 30)]
# Dictionary : {'A': 10, 'B': 20, 'C': 30}

# %% [markdown]
# 7.Given a tuple containing numbers, count how many elements are divisible by 5.

# %%
#7
t = (10, 15, 20, 25, 30, 35, 40)
print(f"The given tupple is : {t}")

count = 0
for i in t:
   if i % 5 == 0:
    count += 1

print(f"The number of elements divisible by 5 are : {count}")
# Out:
# The given tupple is : (10, 15, 20, 25, 30, 35, 40)
# The number of elements divisible by 5 are : 7

# %% [markdown]
# 8.Write a program to merge two tuples and remove duplicate values.
# Example
# Input: (1,2,3) and (3,4,5)
# Output: (1,2,3,4,5)

# %%
#8
t1= (1,2,3)
t2 = (3,4,5)
print(f"The first tuple is {t1}")
print(f"The second tuple is {t2}")

resut = []
merge = t1 + t2
print(f"The merged tuple is {merge}")

for i in merge:
  if i not in result:
    result.append(i)

    final_tuple = tuple(result)

print(f"The final result is {result}")
# Out:
# The first tuple is (1, 2, 3)
# The second tuple is (3, 4, 5)
# The merged tuple is (1, 2, 3, 3, 4, 5)
# The final result is [1, 2, 3, 4, 5]

# %% [markdown]
# 9.Write a Python program to find the student with the highest marks from a dictionary.
# Example
# {'Amit':78, 'Rahul':85, 'Neha':92, 'Riya':88}

# %%
#9
students = {
    "Amit": 78,
    "Rahul": 85,
    "Neha": 92,
    "Riya": 88
}

top_students = ""
max_marks = -1
for name, marks in students.items():
  if marks > max_marks:
    max_marks = marks
    top_students = name

print(f"The student with the highest marks is {top_students}")
# Out:
# The student with the highest marks is Neha

# %% [markdown]
# 10.Given a dictionary of items and prices, calculate the total cost of all items.
# Example
# {'Pen':10, 'Book':50, 'Pencil':5}

# %%
#10
Items = {
    "pen":10,
    "Book":50,
    "Pencil":5
}

Total = 0
for name,cost in Items.items():
  Total += cost
print(f"The total cost is {Total}")
# Out:
# The total cost is 65

# %% [markdown]
# 11.Write a program to count the occurrence of each character in a string using dictionary.
# Example
# Input: "programming"

# %%
#11
s = str(input("Enter the string : "))

fr = {}
for char in s:
  if char in fr:
    fr[char] += 1
  else:
    fr[char] = 1

print(f"The frequency of each character is {fr}")
# Out:
# Enter the string : programming
# The frequency of each character is {'p': 1, 'r': 2, 'o': 1, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1, ' ': 1}

# %% [markdown]
# 12.Write a function isPrime(n) that checks whether a number is prime or not.

# %%
#12
def isPrime(n):
    if n <= 1:
        return False

    for i in range(2, n):
        if n % i == 0:
            return False

    return True

num = int(input("Enter a number: "))

if isPrime(num):
    print(num, "is a Prime Number")
else:
    print(num, "is not a Prime Number")
# Out:
# 10 is not a Prime Number

# %% [markdown]
# 13.Write a function that returns the factorial of a number using recursion.

# %%
#13
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n-1)

num = int(input("Enter a number: "))

result = factorial(num)

print("Factorial of", num, "is", result)
# Out:
# Factorial of 6 is 720

# %% [markdown]
# 14.Write a function count_vowels(string) that counts the number of vowels in a string.
# Example
# Input: "Artificial Intelligence"

# %%
#14
def count_vowels(string):
    count = 0
    vowels = "aeiouAEIOU"

    for char in string:
        if char in vowels:
            count += 1

    return count


text = input("Enter a string: ")
result = count_vowels(text)

print("Number of vowels:", result)
# Out:
# Number of vowels: 10

# %% [markdown]
# 15.Write a function that accepts a list and returns the sum of all elements divisible by 3.

# %%
#15
def sum_divisible_by_3(lst):
    total = 0

    for num in lst:
        if num % 3 == 0:
            total += num

    return total

numbers = list(map(int, input("Enter elements separated by space: ").split()))

print(f"The given list is {numbers}")

result = sum_divisible_by_3(numbers)

print("Sum of numbers divisible by 3:", result)
# Out:
# The given list is [3, 5, 9, 12, 15, 18, 20, 21]
# Sum of numbers divisible by 3: 78

# %% [markdown]
# 16.Write a function that takes a list of numbers and returns a new list containing only prime numbers.
# Example
# Input: [10,11,12,13,14,17]
# Output: [11,13,17]

# %%
#16
def isPrime(n):
    if n <= 1:
        return False

    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False

    return True


def get_primes(lst):
    prime_list = []

    for num in lst:
        if isPrime(num):
            prime_list.append(num)

    return prime_list


numbers = list(map(int, input("Enter numbers separated by space: ").split()))

result = get_primes(numbers)

print("Prime numbers:", result)
# Out:
# Enter numbers separated by space: 10 11 12 13 14 17
# Prime numbers: [11, 13, 17]

# %% [markdown]
# 17.Write a function that takes a list and returns a dictionary where keys are list elements and values are their
# frequencies.

# %%
def frequency_dict(lst):
  freq = {}

    for element in lst:
        if element in freq:
            freq[element] += 1
        else:
            freq[element] = 1

    return freq

numbers = list(map(int, input("Enter elements separated by space: ").split()))
result = frequency_dict(numbers)

print("Frequency dictionary:", result)

# %% [markdown]
# 18.Write a program to group words by their length using dictionary.
# Example
# Input: ["AI","Python","ML","Data"]

# %%
#18
def group_by_length(words):
    result = {}

    for word in words:
        length = len(word)

        if length not in result:
            result[length] = []

        result[length].append(word)

    return result


# Driver code
words = ["AI", "Python", "ML", "Data"]

output = group_by_length(words)

print("Grouped words:", output)

# %% [markdown]
# 19.Given a list of tuples representing (student_name, marks), sort them by marks using a function.

# %%
#19
def sort_by_marks(student_list):
    return sorted(student_list, key=lambda x: x[1])


# Driver code
students = [("Rahul", 78), ("Anita", 92), ("Karan", 65), ("Sneha", 85)]

result = sort_by_marks(students)

print("Sorted by marks:", result)

# %% [markdown]
# 20.Write a Python function that returns the most frequent element in a list.

# %%
#20
def most_frequent(lst):
    freq = {}

    # Count frequency of each element
    for i in lst:
        if i in freq:
            freq[i] += 1
        else:
            freq[i] = 1

    # Find element with maximum frequency
    max_element = max(freq, key=freq.get)

    return max_element


# Driver code
numbers = list(map(int, input("Enter elements separated by space: ").split()))

result = most_frequent(numbers)

print("Most frequent element:", result)
